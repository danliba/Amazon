# %%
import xarray as xr

# %%
U = xr.open_dataset("W_2014-04.nc")
print(U)
# Out:
# <xarray.Dataset> Size: 9GB
# Dimensions:      (time: 30, k: 50, j: 1201, i: 1201)
# Coordinates: (12/17)
#   * time         (time) datetime64[ns] 240B 2014-04-01 2014-04-02 ... 2014-04-30
#   * k            (k) int64 400B 0 1 2 3 4 5 6 7 8 ... 41 42 43 44 45 46 47 48 49
#   * j            (j) int64 10kB 0 1 2 3 4 5 6 ... 1195 1196 1197 1198 1199 1200
#   * i            (i) int64 10kB 0 1 2 3 4 5 6 ... 1195 1196 1197 1198 1199 1200
#     depth_t      (k) float32 200B ...
#     latitude_f   (j) float32 5kB ...
#     ...           ...
#     longitude_v  (i) float32 5kB ...
#     latitude_t   (j) float32 5kB ...
#     longitude_t  (i) float32 5kB ...
#     dz_t         (k) float32 200B ...
#     dx_t         (j) float64 10kB ...
#     dy_t         float64 8B ...
# Data variables:
#     w_c          (time, k, j, i) float32 9GB ...

# %%
U
# Out:
# <xarray.Dataset> Size: 9GB
# Dimensions:      (time: 30, k: 50, j: 1201, i: 1201)
# Coordinates: (12/17)
#   * time         (time) datetime64[ns] 240B 2014-04-01 2014-04-02 ... 2014-04-30
#   * k            (k) int64 400B 0 1 2 3 4 5 6 7 8 ... 41 42 43 44 45 46 47 48 49
#   * j            (j) int64 10kB 0 1 2 3 4 5 6 ... 1195 1196 1197 1198 1199 1200
#   * i            (i) int64 10kB 0 1 2 3 4 5 6 ... 1195 1196 1197 1198 1199 1200
#     depth_t      (k) float32 200B ...
#     latitude_f   (j) float32 5kB ...
#     ...           ...
#     longitude_v  (i) float32 5kB ...
#     latitude_t   (j) float32 5kB ...
#     longitude_t  (i) float32 5kB ...
#     dz_t         (k) float32 200B ...
#     dx_t         (j) float64 10kB ...
#     dy_t         float64 8B ...
# Data variables:
#     w_c          (time, k, j, i) float32 9GB ...

# %%
print("Time dimension:", U.time.size)
print("Data shape:", U.w_c.shape)
print("Time values:", U.time.values[:3])
# Out:
# Time dimension: 30
# Data shape: (30, 50, 1201, 1201)
# Time values: ['2014-04-01T00:00:00.000000000' '2014-04-02T00:00:00.000000000'
#  '2014-04-03T00:00:00.000000000']
