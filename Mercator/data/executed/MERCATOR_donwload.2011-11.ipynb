# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [14]</a>'.</span>

# %%
year = 2007
month = 1

# %%
# Parameters
year = 2011
month = 11

# %%
import numpy as np
import pandas as pd
import xarray as xr
import os, pathlib, stat, textwrap
import calendar
import datetime
from datetime import date

# %% [markdown]
# ### URLs

# %%
# Ufiles = "https://tds.mercator-ocean.fr/thredds/dodsC/glorys12v1-daily-gridU"
Ufiles = "dap2://tds.mercator-ocean.fr/thredds/dodsC/glorys12v1-daily-gridU"
Vfiles = "dap2://tds.mercator-ocean.fr/thredds/dodsC/glorys12v1-daily-gridV"
Wfiles = "dap2://tds.mercator-ocean.fr/thredds/dodsC/glorys12v1-daily-gridW"
Tfiles = "dap2://tds.mercator-ocean.fr/thredds/dodsC/glorys12v1-daily-gridT"
Sfiles = "dap2://tds.mercator-ocean.fr/thredds/dodsC/glorys12v1-daily-gridS"
# #mesh url
# Zgr = "http://tds.mercator-ocean.fr/thredds/dodsC/glorys12v1/glorys12v1-pgnstatics/PSY4V3R1_mesh_zgr.nc"
# Hgr = "http://tds.mercator-ocean.fr/thredds/dodsC/glorys12v1/glorys12v1-pgnstatics/PSY4V3R1_mesh_hgr.nc"

# %% [markdown]
# ### Environment

# %%
os.environ["NETRC"] = "/home/b/b383184/.netrc"

# %% [markdown]
# ### Mesh

# %%
ds_Zgr = xr.open_dataset('../data/Zgr_mesh.nc')
ds_Zgr
# Out:
# <xarray.Dataset> Size: 555MB
# Dimensions:       (y: 3059, x: 4322, z: 50, t: 1)
# Dimensions without coordinates: y, x, z, t
# Data variables: (12/13)
#     nav_lon       (y, x) float32 53MB ...
#     nav_lat       (y, x) float32 53MB ...
#     nav_lev       (z) float32 200B ...
#     time_counter  (t) float64 8B ...
#     mbathy        (t, y, x) int16 26MB ...
#     hdept         (t, y, x) float64 106MB ...
#     ...            ...
#     e3t_ps        (t, y, x) float64 106MB ...
#     e3w_ps        (t, y, x) float64 106MB ...
#     gdept_0       (t, z) float64 400B ...
#     gdepw_0       (t, z) float64 400B ...
#     e3t_0         (t, z) float64 400B ...
#     e3w_0         (t, z) float64 400B ...
# Attributes:
#     file_name:            mesh_zgr.nc
#     TimeStamp:            03/02/2016 10:24:41 -0000
#     Unlimited_Dimension:  t

# %%
ds_Hgr = xr.open_dataset('../data/Hgr_mesh.nc')
ds_Hgr
# Out:
# <xarray.Dataset> Size: 1GB
# Dimensions:       (y: 3059, x: 4322, z: 50, t: 1)
# Dimensions without coordinates: y, x, z, t
# Data variables: (12/21)
#     nav_lon       (y, x) float32 53MB ...
#     nav_lat       (y, x) float32 53MB ...
#     nav_lev       (z) float32 200B ...
#     time_counter  (t) float64 8B ...
#     glamt         (t, y, x) float32 53MB ...
#     glamu         (t, y, x) float32 53MB ...
#     ...            ...
#     e1f           (t, y, x) float64 106MB ...
#     e2t           (t, y, x) float64 106MB ...
#     e2u           (t, y, x) float64 106MB ...
#     e2v           (t, y, x) float64 106MB ...
#     e2f           (t, y, x) float64 106MB ...
#     ff            (t, y, x) float64 106MB ...
# Attributes:
#     file_name:            mesh_hgr.nc
#     TimeStamp:            03/02/2016 10:24:55 -0000
#     Unlimited_Dimension:  t

# %% [markdown]
# ### Functions

# %%
lon0, lon1 = -95, 10
lat0, lat1 = -10, 30

# 1) Use T-point lon/lat
lonT = ds_Hgr.glamt.isel(t=0)
latT = ds_Hgr.gphit.isel(t=0)

# 2) Build boolean mask for your box
mask = (lonT >= lon0) & (lonT <= lon1) & (latT >= lat0) & (latT <= lat1)

# 3) Get index ranges
yy, xx = np.where(mask.values)

y0, y1 = int(yy.min()), int(yy.max())
x0, x1 = int(xx.min()), int(xx.max())

x0, x1, y0, y1
# Out:
# (2305, 3565, 1374, 1873)

# %%
last_day = calendar.monthrange(year, month)[1]
start_date = datetime.datetime(year, month, 1)
end_date = datetime.datetime(year, month, last_day)

print(end_date.strftime("%Y-%m-%d"))
# Out:
# 2011-11-30

# %%
def glorys_days(start_date, end_date):
    return pd.date_range(start=start_date, end=end_date, freq="D") + pd.Timedelta(hours=12)

days = glorys_days(start_date.strftime("%Y-%m-%d")
                   , end_date.strftime("%Y-%m-%d"))

# %%
def download_MERCATOR(url, varname, starts, ends, x0, x1, y0, y1, output_file):

    from tqdm import tqdm
    import xarray as xr
    
    parts = []
    for tt in tqdm(range(len(days)//2)):
        da = (
            xr.open_dataset(url, engine="pydap", mask_and_scale=False, decode_cf=True)[varname]
            .sortby("time_counter")
            .isel(x=slice(x0, x1), y=slice(y0, y1))
            .sel(time_counter=slice(starts[tt], ends[tt]))
            .astype("float32")
            .load()
        )
        parts.append(da)
    
    da_all = xr.concat(parts, dim="time_counter")
    da_all.to_dataset(name=varname).to_netcdf(output_file, unlimited_dims=["time_counter"])
    print(f"Saved {output_file}")

# %%
starts = days[0::2]
ends = days[1::2].tolist()  
ends[-1] = days[-1]
ends

for tt in  range(len(days)//2):
    print('start_date '+str(starts[tt]))
    print('end_date '+str(ends[tt]))
# Out:
# start_date 2011-11-01 12:00:00
# end_date 2011-11-02 12:00:00
# start_date 2011-11-03 12:00:00
# end_date 2011-11-04 12:00:00
# start_date 2011-11-05 12:00:00
# end_date 2011-11-06 12:00:00
# start_date 2011-11-07 12:00:00
# end_date 2011-11-08 12:00:00
# start_date 2011-11-09 12:00:00
# end_date 2011-11-10 12:00:00
# start_date 2011-11-11 12:00:00
# end_date 2011-11-12 12:00:00
# start_date 2011-11-13 12:00:00
# end_date 2011-11-14 12:00:00
# start_date 2011-11-15 12:00:00
# end_date 2011-11-16 12:00:00
# start_date 2011-11-17 12:00:00
# end_date 2011-11-18 12:00:00
# start_date 2011-11-19 12:00:00
# end_date 2011-11-20 12:00:00
# start_date 2011-11-21 12:00:00
# end_date 2011-11-22 12:00:00
# start_date 2011-11-23 12:00:00
# end_date 2011-11-24 12:00:00
# start_date 2011-11-25 12:00:00
# end_date 2011-11-26 12:00:00
# start_date 2011-11-27 12:00:00
# end_date 2011-11-28 12:00:00
# start_date 2011-11-29 12:00:00
# end_date 2011-11-30 12:00:00

# %% [markdown]
# ### Data download

# %%
U_out = f'U_{start_date.strftime("%Y-%m")}.nc'
V_out = f'V_{start_date.strftime("%Y-%m")}.nc'
W_out = f'W_{start_date.strftime("%Y-%m")}.nc'
T_out = f'T_{start_date.strftime("%Y-%m")}.nc'
S_out = f'S_{start_date.strftime("%Y-%m")}.nc'

outpath = '/work/bk1450/b383184/Amazon/Mercator/data/variables/'

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
#U 
download_MERCATOR(
    Ufiles, "vozocrtx", starts, ends, x0, x1, y0, y1,outpath+U_out
)
# Out:
#   0%|                                                                                                       | 0/15 [00:00<?, ?it/s]
# /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/pydap/handlers/dap.py:775: RuntimeWarning: overflow encountered in scalar multiply
#   count = response_dtype.itemsize * n
#   7%|██████▎                                                                                       | 1/15 [04:16<59:53, 256.67s/it]
#  13%|████████████▌                                                                                 | 2/15 [08:15<53:20, 246.16s/it]
# /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/pydap/handlers/dap.py:775: RuntimeWarning: overflow encountered in scalar multiply
#   count = response_dtype.itemsize * n
#  20%|██████████████████▊                                                                           | 3/15 [11:14<43:03, 215.32s/it]
#  27%|█████████████████████████                                                                     | 4/15 [15:41<43:14, 235.84s/it]
#  33%|███████████████████████████████▎                                                              | 5/15 [23:55<54:49, 328.90s/it]
# /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/pydap/handlers/dap.py:775: RuntimeWarning: overflow encountered in scalar multiply
#   count = response_dtype.itemsize * n
#  40%|█████████████████████████████████████▌                                                        | 6/15 [25:22<37:01, 246.78s/it]
#  47%|███████████████████████████████████████████▊                                                  | 7/15 [27:02<26:29, 198.72s/it]
#  53%|██████████████████████████████████████████████████▏                                           | 8/15 [28:45<19:37, 168.22s/it]
#  60%|████████████████████████████████████████████████████████▍                                     | 9/15 [29:19<12:38, 126.35s/it]
#  60%|████████████████████████████████████████████████████████▍                                     | 9/15 [31:28<20:59, 209.84s/it]
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/urllib3/response.py:779, in HTTPResponse._error_catcher(self)
#     778 try:
# --> 779     yield
#     781 except SocketTimeout as e:
#     782     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     783     # there is yet no clean way to get at it from this context.
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/urllib3/response.py:1248, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1247 while True:
# -> 1248     self._update_chunk_length()
#    1249     if self.chunk_left == 0:
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/urllib3/response.py:1167, in HTTPResponse._update_chunk_length(self)
#    1166     return None
# -> 1167 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1168 line = line.split(b";", 1)[0]
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     819 try:
# --> 820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/urllib3/response.py:1088, in HTTPResponse.stream(self, amt, decode_content)
#    1087 if self.chunked and self.supports_chunked_reads():
# -> 1088     yield from self.read_chunked(amt, decode_content=decode_content)
#    1089 else:
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/urllib3/response.py:1231, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1226     raise BodyNotHttplibCompatible(
#    1227         "Body should be http.client.HTTPResponse like. "
#    1228         "It should have have an fp attribute which returns raw chunks."
#    1229     )
# -> 1231 with self._error_catcher():
#    1232     # Don't bother reading the body of a HEAD request.
#    1233     if self._original_response and is_response_to_head(self._original_response):
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/urllib3/response.py:784, in HTTPResponse._error_catcher(self)
#     781 except SocketTimeout as e:
#     782     # FIXME: Ideally we'd like to include the url in the ReadTimeoutError but
#     783     # there is yet no clean way to get at it from this context.
# --> 784     raise ReadTimeoutError(self._pool, None, "Read timed out.") from e  # type: ignore[arg-type]
#     786 except BaseSSLError as e:
#     787     # FIXME: Is there a better way to differentiate between SSLErrors?
#
# ReadTimeoutError: HTTPSConnectionPool(host='tds.mercator-ocean.fr', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[14], line 2
#       1 #U
# ----> 2 download_MERCATOR(
#       3     Ufiles, "vozocrtx", starts, ends, x0, x1, y0, y1,outpath+U_out
#       4 )
#
# Cell In[11], line 13, in download_MERCATOR(url, varname, starts, ends, x0, x1, y0, y1, output_file)
#       6 parts = []
#       7 for tt in tqdm(range(len(days)//2)):
#       8     da = (
#       9         xr.open_dataset(url, engine="pydap", mask_and_scale=False, decode_cf=True)[varname]
#      10         .sortby("time_counter")
#      11         .isel(x=slice(x0, x1), y=slice(y0, y1))
#      12         .sel(time_counter=slice(starts[tt], ends[tt]))
# ---> 13         .astype("float32")
#      14         .load()
#      15     )
#      16     parts.append(da)
#      18 da_all = xr.concat(parts, dim="time_counter")
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/core/common.py:1484, in DataWithCoords.astype(self, dtype, order, casting, subok, copy, keep_attrs)
#    1481 kwargs = dict(order=order, casting=casting, subok=subok, copy=copy)
#    1482 kwargs = {k: v for k, v in kwargs.items() if v is not None}
# -> 1484 return apply_ufunc(
#    1485     duck_array_ops.astype,
#    1486     self,
#    1487     dtype,
#    1488     kwargs=kwargs,
#    1489     keep_attrs=keep_attrs,
#    1490     dask="allowed",
#    1491 )
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:1263, in apply_ufunc(func, input_core_dims, output_core_dims, exclude_dims, vectorize, join, dataset_join, dataset_fill_value, keep_attrs, kwargs, dask, output_dtypes, output_sizes, meta, dask_gufunc_kwargs, on_missing_core_dim, *args)
#    1261 # feed DataArray apply_variable_ufunc through apply_dataarray_vfunc
#    1262 elif any(isinstance(a, DataArray) for a in args):
# -> 1263     return apply_dataarray_vfunc(
#    1264         variables_vfunc,
#    1265         *args,
#    1266         signature=signature,
#    1267         join=join,
#    1268         exclude_dims=exclude_dims,
#    1269         keep_attrs=keep_attrs,
#    1270     )
#    1271 # feed Variables directly through apply_variable_ufunc
#    1272 elif any(isinstance(a, Variable) for a in args):
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:305, in apply_dataarray_vfunc(func, signature, join, exclude_dims, keep_attrs, *args)
#     300 result_coords, result_indexes = build_output_coords_and_indexes(
#     301     args, signature, exclude_dims, combine_attrs=keep_attrs
#     302 )
#     304 data_vars = [getattr(a, "variable", a) for a in args]
# --> 305 result_var = func(*data_vars)
#     307 out: tuple[DataArray, ...] | DataArray
#     308 if signature.num_outputs > 1:
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:726, in apply_variable_ufunc(func, signature, exclude_dims, dask, output_dtypes, vectorize, keep_attrs, dask_gufunc_kwargs, *args)
#     719 broadcast_dims = tuple(
#     720     dim for dim in dim_sizes if dim not in signature.all_core_dims
#     721 )
#     722 output_dims = [broadcast_dims + out for out in signature.output_core_dims]
#     724 input_data = [
#     725     (
# --> 726         broadcast_compat_data(arg, broadcast_dims, core_dims)
#     727         if isinstance(arg, Variable)
#     728         else arg
#     729     )
#     730     for arg, core_dims in zip(args, signature.input_core_dims, strict=True)
#     731 ]
#     733 if any(is_chunked_array(array) for array in input_data):
#     734     if dask == "forbidden":
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/computation/apply_ufunc.py:647, in broadcast_compat_data(variable, broadcast_dims, core_dims)
#     642 def broadcast_compat_data(
#     643     variable: Variable,
#     644     broadcast_dims: tuple[Hashable, ...],
#     645     core_dims: tuple[Hashable, ...],
#     646 ) -> Any:
# --> 647     data = variable.data
#     649     old_dims = variable.dims
#     650     new_dims = broadcast_dims + core_dims
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/core/variable.py:430, in Variable.data(self)
#     428     duck_array = self._data.array
#     429 elif isinstance(self._data, indexing.ExplicitlyIndexed):
# --> 430     duck_array = self._data.get_duck_array()
#     431 elif is_duck_array(self._data):
#     432     duck_array = self._data
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/core/indexing.py:845, in MemoryCachedArray.get_duck_array(self)
#     844 def get_duck_array(self):
# --> 845     self._ensure_cached()
#     846     return self.array.get_duck_array()
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/core/indexing.py:842, in MemoryCachedArray._ensure_cached(self)
#     841 def _ensure_cached(self):
# --> 842     self.array = as_indexable(self.array.get_duck_array())
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/core/indexing.py:799, in CopyOnWriteArray.get_duck_array(self)
#     798 def get_duck_array(self):
# --> 799     return self.array.get_duck_array()
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/core/indexing.py:650, in LazilyIndexedArray.get_duck_array(self)
#     648 def get_duck_array(self):
#     649     if isinstance(self.array, ExplicitlyIndexedNDArrayMixin):
# --> 650         array = apply_indexer(self.array, self.key)
#     651     else:
#     652         # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     653         # it may wrap a BackendArray so use its __getitem__
#     654         array = self.array[self.key]
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/core/indexing.py:1036, in apply_indexer(indexable, indexer)
#    1034     return indexable.vindex[indexer]
#    1035 elif isinstance(indexer, OuterIndexer):
# -> 1036     return indexable.oindex[indexer]
#    1037 else:
#    1038     return indexable[indexer]
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/core/indexing.py:372, in IndexCallable.__getitem__(self, key)
#     371 def __getitem__(self, key: Any) -> Any:
# --> 372     return self.getter(key)
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/coding/variables.py:61, in NativeEndiannessArray._oindex_get(self, key)
#      60 def _oindex_get(self, key):
# ---> 61     return np.asarray(self.array.oindex[key], dtype=self.dtype)
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/core/indexing.py:511, in ExplicitlyIndexed.__array__(self, dtype, copy)
#     506 def __array__(
#     507     self, dtype: np.typing.DTypeLike = None, /, *, copy: bool | None = None
#     508 ) -> np.ndarray:
#     509     # Leave casting to an array up to the underlying array type.
#     510     if Version(np.__version__) >= Version("2.0.0"):
# --> 511         return np.asarray(self.get_duck_array(), dtype=dtype, copy=copy)
#     512     else:
#     513         return np.asarray(self.get_duck_array(), dtype=dtype)
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/core/indexing.py:654, in LazilyIndexedArray.get_duck_array(self)
#     650     array = apply_indexer(self.array, self.key)
#     651 else:
#     652     # If the array is not an ExplicitlyIndexedNDArrayMixin,
#     653     # it may wrap a BackendArray so use its __getitem__
# --> 654     array = self.array[self.key]
#     656 # self.array[self.key] is now a numpy array when
#     657 # self.array is a BackendArray subclass
#     658 # and self.key is BasicIndexer((slice(None, None, None),))
#     659 # so we need the explicit check for ExplicitlyIndexed
#     660 if isinstance(array, ExplicitlyIndexed):
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/backends/pydap_.py:49, in PydapArrayWrapper.__getitem__(self, key)
#      48 def __getitem__(self, key):
# ---> 49     return indexing.explicit_indexing_adapter(
#      50         key, self.shape, indexing.IndexingSupport.BASIC, self._getitem
#      51     )
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/core/indexing.py:1023, in explicit_indexing_adapter(key, shape, indexing_support, raw_indexing_method)
#    1001 """Support explicit indexing by delegating to a raw indexing method.
#    1002
#    1003 Outer and/or vectorized indexers are supported by indexing a second time
#    (...)   1020 Indexing result, in the form of a duck numpy-array.
#    1021 """
#    1022 raw_key, numpy_indices = decompose_indexer(key, shape, indexing_support)
# -> 1023 result = raw_indexing_method(raw_key.tuple)
#    1024 if numpy_indices.tuple:
#    1025     # index the loaded duck array
#    1026     indexable = as_indexable(result)
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/backends/pydap_.py:54, in PydapArrayWrapper._getitem(self, key)
#      53 def _getitem(self, key):
# ---> 54     result = robust_getitem(self.array, key, catch=ValueError)
#      55     # in some cases, pydap doesn't squeeze axes automatically like numpy
#      56     result = np.asarray(result)
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/xarray/backends/common.py:256, in robust_getitem(array, key, catch, max_retries, initial_delay)
#     254 for n in range(max_retries + 1):
#     255     try:
# --> 256         return array[key]
#     257     except catch:
#     258         if n == max_retries:
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/pydap/model.py:1452, in GridType.__getitem__(self, key)
#    1450 else:
#    1451     if not self.output_grid:
# -> 1452         return self.array[key]
#    1454     if not isinstance(key, tuple):
#    1455         key = (key,)
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/pydap/model.py:526, in BaseType.__getitem__(self, index)
#     523     return out
#     525 out = copy.copy(self)
# --> 526 data = self._get_data_index(index)
#     528 # Check if index is a full slice (e.g., [:], ..., or tuple of all slice(None))
#     529 if (
#     530     index == slice(None)
#     531     or index == Ellipsis
#     532     or (isinstance(index, tuple) and all(i == slice(None) for i in index))
#     533 ):
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/pydap/model.py:575, in BaseType._get_data_index(self, index)
#     571     return np.vectorize(decode_np_strings, otypes=self._data.dtype.char)(
#     572         self._data[index]
#     573     )
#     574 else:
# --> 575     return self._get_data()[index]
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/pydap/handlers/dap.py:428, in BaseProxyDap2.__getitem__(self, index)
#     418 logger.info("Fetching URL: %s" % url)
#     419 r = GET(
#     420     url,
#     421     self.application,
#    (...)    425     get_kwargs=self.get_kwargs,
#     426 )
# --> 428 dds, data = safe_dds_and_data(r, self.user_charset)
#     430 # Parse received dataset:
#     431 dataset = dds_to_dataset(dds)
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/pydap/handlers/dap.py:357, in safe_dds_and_data(r, user_charset)
#     355     dds = _dds.decode(get_charset(r, user_charset))
#     356 elif isinstance(r, requests.Response):
# --> 357     raw = r.content
#     358     _dds, data = raw.split(b"\nData:\n", 1)
#     359     dds = _dds.decode(user_charset)
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File /work/bk1450/b383184/conda/envs/parcels_3.1.2/lib/python3.13/site-packages/requests/models.py:826, in Response.iter_content.<locals>.generate()
#     824     raise ContentDecodingError(e)
#     825 except ReadTimeoutError as e:
# --> 826     raise ConnectionError(e)
#     827 except SSLError as e:
#     828     raise RequestsSSLError(e)
#
# ConnectionError: HTTPSConnectionPool(host='tds.mercator-ocean.fr', port=443): Read timed out.

# %%
download_MERCATOR(
    Vfiles, "vomecrty", starts, ends, x0, x1, y0, y1,outpath+V_out 
)

# %%
download_MERCATOR(
    Wfiles, "vovecrtz", starts, ends, x0, x1, y0, y1,outpath+W_out 
)

# %%
download_MERCATOR(
    Tfiles, "votemper", starts, ends, x0, x1, y0, y1,outpath+T_out
)

# %%
download_MERCATOR(
    Sfiles, "vosaline", starts, ends, x0, x1, y0, y1,outpath+S_out 
)
